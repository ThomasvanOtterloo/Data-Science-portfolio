# %%
import pandas as pd
import seaborn as sns
p = sns.load_dataset("penguins")

# %%
p.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
table = p.corr()

# %%
table.style.background_gradient(cmap='coolwarm', axis=None).format(precision=1)
# Out:
# <style type="text/css">
# #T_6b765_row0_col0, #T_6b765_row1_col1, #T_6b765_row2_col2, #T_6b765_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6b765_row0_col1, #T_6b765_row1_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_6b765_row0_col2, #T_6b765_row2_col0 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_6b765_row0_col3, #T_6b765_row3_col0 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_6b765_row1_col2, #T_6b765_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_6b765_row1_col3, #T_6b765_row3_col1 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_6b765_row2_col3, #T_6b765_row3_col2 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6b765">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6b765_level0_col0" class="col_heading level0 col0" >bill_length_mm</th>
# ...

# %% [markdown]
# They meet my expectations. I can see why the body mass has a better correlation with flipper length and bill length, rather than the bill depth. The columns makes sense. (1 positive ,0 weak, -1 negative correlations)

# %%
p.drop([], axis=1).plot(figsize=(15,8))
# Out:
# <AxesSubplot:>

# %%
p.plot(kind='scatter', x='body_mass_g', y='flipper_length_mm')
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
p.plot(kind='scatter', x='flipper_length_mm', y='bill_depth_mm')
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='bill_depth_mm'>

# %%
p.plot(kind='scatter', x='bill_length_mm', y='bill_depth_mm')
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='bill_depth_mm'>
